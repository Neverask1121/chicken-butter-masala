# %% [markdown]
# # Objects and classes in OOP

# %%
class Car:
  pass

audi=Car()
bmw=Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)

# %%
## Instances Variables and Methods

audi.windows = 4
print(audi.windows)
# Out:
# 4

# %%
tata = Car()
tata.doors = 4

# %%
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(tata.windows)
#
# AttributeError: 'Car' object has no attribute 'windows'

# %%
## Imp functions
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
## Incstances variables and Methods

class Dog:
  ## constructor
  ## self is a keyword we can write any name
  def __init__(self, name, age):
    self.name = name
    self.age = age

  ## Create the objects

  dog1=Dog("DOG", 67)
  print(dog1.name)
  print(dog1.age)
# Out:
# DOG
# 67

# %%
dog2 = Dog("Nigga", 3)
print(dog2.name)
print(dog2.age)
# Out:
# Nigga
# 3

# %%
## Creating a instance 

class Dog:
  def __init__ (self, name, age):
    self.name = name
    self.age = age

  def bark(self):
    print(f"{self.name} says bow bow")


dog1 = Dog("Buddy", 3)
dog1.bark()
dog2 = Dog("nigga", 5)
dog2.bark()
# Out:
# Buddy says bow bow
# nigga says bow bow

# %%
## Modelling a bank account

## Define a class for a bank account

class BankAccount:
  def __init__(self, owner, balance=0):
    self.owner = owner
    self.balance = balance

  def deposit(self, amount):
    self.balance += amount
    print(f"{self.balance} is the balance and the deposited account {amount}")
  
  def withdraw(self, amount):
    if amount>self.balance:
      print("The amount cannot be installed")
    else:
      self.balance-=amount
      print(f"The amount {amount} has been installed and the current balance is {self.balance}")
      
  def GetBalance(self):
    return self.balance
  
## craeting a bank account 

account = BankAccount("Aditya", 100000000)
print(account.balance)
# Out:
# 100000000

# %%
account.deposit(500)
# Out:
# 100000500 is the balance and the deposited account 500

# %%
account.withdraw(410000)
# Out:
# The amount 410000 has been installed and the current balance is 99590500

# %%
print(account.GetBalance())
# Out:
# 100000000

# %%
## OOPS is very important for the real world scenarios such as this example

# %% [markdown]
# # Inheritance in Python

# %%
## Inheritance(Single inheritance)
## Parent Class

class Car:
  def __init__(self, windows, doors, enginetype):
    self.windows=windows
    self.doors=doors
    self.enginetype=enginetype

  def drive(self):
    print(f"The person will drive {self.enginetype} car")

# %%
car1 = Car(4,5,"petrol")
print(car1.drive())
# Out:
# The person will drive petrol car
# None

# %%
car1.drive()
# Out:
# The person will drive petrol car

# %%
## Inheriting the particular class into a child class

class Tesla(Car):
  def __init__(self, windows, doors, enginetype, is_self_driving):
    super().__init__(windows, doors, enginetype)
    self.is_self_driving=is_self_driving;
  def selfDriving(self):
    print(f"Tesla supports self driving True or False? {self.is_self_driving}")

# %%
tesla1 = Tesla(4,5,"electric", True)
print(tesla1.selfDriving())
# Out:
# Tesla supports self driving True or False? True
# None

# %%
tesla1.drive()
# Out:
# The person will drive electric car

# %%
## Multiple inheritance
## When a class inherits from more than one base class
## Base class 1
class Animal:
  def __init__(self, name):
    self.name=name;
  def speak(self):
    print("Subclasses must implement this method")

## Base class two
class Pet:
  def __init__(self, owner):
    self.owner=owner

## Derived class
class Dog(Animal, Pet):
  def __init__(self, name, owner):
    Animal.__init__(self,name)
    Pet.__init__(self,owner)

  def speak(self):
    return f"{self.name} says bow bow"
  
## Create an object to see whether working

dog = Dog("Aman", "Aditya")
print(dog.speak())

print(f"Owner:{dog.owner}")
# Out:
# Aman says bow bow
# Owner:Aditya

# %% [markdown]
# # Polymorphism

# %%
### Method Overriding

## Base class

class Animal:
  def speak(self):
    return "Sound of the Animal"
  
## Derived class 1

class Dog(Animal):
  def speak(self):
    return "Woof!"
  
## Derived class 2

class Cat(Animal):
  def speak(self):
    return "Meow!"
  

## Function that demonstrated polymorphism
def animal_speak(animal):
  print(animal.speak())


dog=Dog()
cat=Cat()
print(dog.speak())
print(cat.speak())
animal_speak(dog)
# Out:
# Woof!
# Meow!
# Woof!

# %%
## Polymorphism with functions and methods
## Base class

class Shape:
  def area(self):
    return "The Area of the figure"
  
## Derived class 1

class Rectangle(Shape):
  def __init__(self, width,  height):
    self.width=width
    self.height=height

  def area(self):
    return self.width*self.height
    
## Derived class 2

class Circle(Shape):
  def __init__(self, radius):
    self.radius=radius
  def area(self):
    return 3.14 *self.radius *self.radius
  
## Function that demonstrates polymorphism

def print_area(shape):
   print(f"the area is {shape.area()}")

rectangle = Rectangle(4,5)
circle=Circle(3)

print_area(rectangle)
print_area(circle)
# Out:
# the area is 20
# the area is 28.259999999999998

# %% [markdown]
# ## Polymorphism with abstract base class

# %%
from abc import ABC,abstractmethod

## Define a abstract class

class Vehicle(ABC):
  @abstractmethod
  def start_engine(self):
    pass

## Derived class

class Car(Vehicle):
  def start_engine(self):
    return "Car engine started"
  
## Derived class 2

class Motorcycle(Vehicle):
  def start_engine(self):
    return "Motorcycle engine has started"
  
## Function that demon pol

def start_vehicle(vehicle):
  print(vehicle.start_engine())

## Create objects of car and Motorcycle

car = Car()
motorcycle=Motorcycle()

start_vehicle(car)
start_vehicle(motorcycle)
# Out:
# Car engine started
# Motorcycle engine has started

# %% [markdown]
# # Encapsulation

# %%
### Encapsulation we can do using the  getter and setter methods

### Public, Protected and Privvate variables

class Person:
  def __init__(self, name, age):
    self.name=name
    ## This is a public variabe
    self.age=age
    ## This is also a public variable

def get_name(person):
  return person.name

person=Person("Aditya", 81)
print(person.name)
get_name(person)
# Out:
# Aditya
# 'Aditya'

# %%
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
### Encapsulation we can do using the  getter and setter methods

### Public, Protected and Privvate variables

class Person:
  def __init__(self, name, age):
    self.__name=name  ## Priavte variable as __
    ## This is a public variabe
    self.__age=age
    ## This is also a public variable
def get_name(person):
  return person._Person__name

person = Person("aditya", 18)
get_name(person)

## definately error will come
# Out:
# 'aditya'

# %%
person=Person("Aditya", 18)
dir(person)
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
### Encapsulation we can do using the  getter and setter methods

### Public, Protected and Privvate variables

class Person:
  def __init__(self, name, age, gender):
    self._name=name  ## Protected variable as _
    ## This is a private variabe
    self._age=age
    ## This is also a public variable
    self.gender=gender

class Employee(Person):
  def __init__(self, name, age, gender):
    super().__init__(name, age, gender)


emplyee=Employee("Aditya", 18, "Male")
print(emplyee._name)
# Out:
# Aditya

# %%
## Encapsulation with getter and setter method


class Person:
  def __init__(self, name, age):
    self.__name=name
    self.__age=age

  ## getter method

  def get_name(self):
    return self.__name
  
  ## setter method

  def set_name(self, name):
    self.__name=name

  ## getter method for the age

  def get_age(self):
    return self.__age

  def set_age(self, age):
    if age > 0:
      self.__age=age
    else:
      print("Age cannot be negative nigga")

  
person=Person("Aditya", 18)

## access and modigy the private variables using getter and setter

print(person.get_name())
print(person.get_age())


person.set_age(17)

print(person.get_age())

person.set_age(-5)
# Out:
# Aditya
# 18
# 17
# Age cannot be negative nigga

# %% [markdown]
# # Abstraction

# %%
from abc import ABC, abstractmethod

## Abstract base class

class Vehicle(ABC):
  def drive(self):
    print("The vehicle is used for driving")  

  @abstractmethod
  def start_engine(self):
    pass

class Car(Vehicle):
  def start_engine(self):
    print('Car engine started')

def operate_vehicle(vehicle):
    vehicle.start_engine()

car=Car()
operate_vehicle(car)
# Out:
# Car engine started

# %% [markdown]
# ## To hide the complex implementation and only show what are used or somethng like that
