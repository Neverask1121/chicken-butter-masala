# %% [markdown]
# # 02-06-2026

# %%
import nltk
paragraph = """Over the past few days, I have been actively contributing to open-source projects by working on documentation improvements, resolving repository issues, and learning the complete GitHub workflow. This involved forking repositories, creating feature branches, synchronizing changes from upstream repositories, handling merge conflicts, and submitting pull requests. Through this process, I gained practical experience with Git commands, version control best practices, and collaborative software development. These contributions have not only improved my technical skills but also helped me better understand how large-scale projects are maintained and managed by developer communities."""

# %%
paragraph
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 paragraph
#
# NameError: name 'paragraph' is not defined
