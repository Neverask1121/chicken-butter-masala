# %% [markdown]
# ## Exception handling

# %%
## Exception handling

a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
## with try and except

try:
  a=b
except:
  print("The variable has not been assigned...")
# Out:
# The variable has not been assigned...

# %%
## with try and except

try:
  a=b
except NameError as ex:
  print(ex)
# Out:
# name 'b' is not defined

# %%
result = 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result = 1/0
#
# ZeroDivisionError: division by zero

# %%
try:
  result=1/2
  a=b
except ZeroDivisionError as Ze: ## only zero division error
  print(Ze)
  print("Please enter the denominator greater than 0")
except Exception as ex1:
  print(ex1) ## At the end of the day the exception was handled
  print("Main exception has been caught here")
# Out:
# name 'b' is not defined
# Main exception has been caught here

# %%
try:
  num = int(input("Enter the number"))
  result = 10/num
except ValueError:
  print("This is not a valid number")
except ZeroDivisionError:
  print("You can not enter 0")
except Exception:
  print(ex)
# Out:
# This is not a valid number

# %%
## try, except and else block

try:
  num = int(input("Enter the number"))
  result = 10/num
except ValueError:
  print("This is not a valid number")
except ZeroDivisionError:
  print("You can not enter 0")
except Exception:
  print(ex)
else:
  print(f"The result is {result}")
finally:
  print("Execution is completed")
# Out:
# The result is 0.22727272727272727
# Execution is completed

# %%
## Practical examples

## File handling and exception handling

try:
  file=open('example1.txt', 'r')
  content = file.read()
  print(content)
except FileNotFoundError:
  print("The file does not exists")
finally:
  if 'file' in locals() and not file.close():
    file.close()
    print('file closed')
# Out:
# Hello My name is Aditya
# file closed
