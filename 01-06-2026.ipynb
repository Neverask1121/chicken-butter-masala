# %%
pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in C:\Users\adity\AppData\Roaming\Python\Python314\site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in C:\Users\adity\AppData\Roaming\Python\Python314\site-packages (from nltk) (1.5.3)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.5.9-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tqdm in C:\Users\adity\AppData\Roaming\Python\Python314\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in C:\Users\adity\AppData\Roaming\Python\Python314\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    -------------------- ------------------- 0.8/1.6 MB 1.7 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 2.0 MB/s  0:00:01
# Downloading regex-2026.5.9-cp314-cp314-win_amd64.whl (280 kB)
# Installing collected packages: regex, nltk
#
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    ---------------------------------------- 2/2 [nltk]
#
# Successfully installed nltk-3.9.4 regex-2026.5.9
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored

# %%
import os
import nltk
nltk.download()
#nltk.download('punkt')
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
AI = ' welcome nigga shit your pants '

# %%
AI
# Out:
# ' welcome nigga shit your pants '

# %%
from nltk.probability import FreqDist
fdlist = FreqDist(AI)
fdlist
# Out:
# FreqDist({' ': 6, 'e': 2, 'o': 2, 'n': 2, 'i': 2, 'g': 2, 'a': 2, 's': 2, 't': 2, 'w': 1, ...})

# %%
from nltk.util import bigrams, trigrams, ngrams
bigrams = list(bigrams(AI))
bigrams
# Out:
# [(' ', 'w'),
#  ('w', 'e'),
#  ('e', 'l'),
#  ('l', 'c'),
#  ('c', 'o'),
#  ('o', 'm'),
#  ('m', 'e'),
#  ('e', ' '),
#  (' ', 'n'),
#  ('n', 'i'),
#  ('i', 'g'),
#  ('g', 'g'),
#  ('g', 'a'),
#  ('a', ' '),
#  (' ', 's'),
#  ('s', 'h'),
#  ('h', 'i'),
#  ('i', 't'),
#  ('t', ' '),
#  (' ', 'y'),
#  ('y', 'o'),
#  ('o', 'u'),
#  ('u', 'r'),
#  ('r', ' '),
#  (' ', 'p'),
#  ('p', 'a'),
#  ('a', 'n'),
#  ('n', 't'),
#  ('t', 's'),
#  ('s', ' ')]

# %%
from nltk.util import bigrams, trigrams, ngrams
ngrams = list(ngrams(AI, 7))
ngrams
# Out:
# [(' ', 'w', 'e', 'l', 'c', 'o', 'm'),
#  ('w', 'e', 'l', 'c', 'o', 'm', 'e'),
#  ('e', 'l', 'c', 'o', 'm', 'e', ' '),
#  ('l', 'c', 'o', 'm', 'e', ' ', 'n'),
#  ('c', 'o', 'm', 'e', ' ', 'n', 'i'),
#  ('o', 'm', 'e', ' ', 'n', 'i', 'g'),
#  ('m', 'e', ' ', 'n', 'i', 'g', 'g'),
#  ('e', ' ', 'n', 'i', 'g', 'g', 'a'),
#  (' ', 'n', 'i', 'g', 'g', 'a', ' '),
#  ('n', 'i', 'g', 'g', 'a', ' ', 's'),
#  ('i', 'g', 'g', 'a', ' ', 's', 'h'),
#  ('g', 'g', 'a', ' ', 's', 'h', 'i'),
#  ('g', 'a', ' ', 's', 'h', 'i', 't'),
#  ('a', ' ', 's', 'h', 'i', 't', ' '),
#  (' ', 's', 'h', 'i', 't', ' ', 'y'),
#  ('s', 'h', 'i', 't', ' ', 'y', 'o'),
#  ('h', 'i', 't', ' ', 'y', 'o', 'u'),
#  ('i', 't', ' ', 'y', 'o', 'u', 'r'),
#  ('t', ' ', 'y', 'o', 'u', 'r', ' '),
#  (' ', 'y', 'o', 'u', 'r', ' ', 'p'),
#  ('y', 'o', 'u', 'r', ' ', 'p', 'a'),
#  ('o', 'u', 'r', ' ', 'p', 'a', 'n'),
#  ('u', 'r', ' ', 'p', 'a', 'n', 't'),
#  ('r', ' ', 'p', 'a', 'n', 't', 's'),
#  (' ', 'p', 'a', 'n', 't', 's', ' ')]
