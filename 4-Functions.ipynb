# %%
## syntax of functions

def function_name(parameters):
    """Docstring"""
    # Function body
    return expression

# %%
def even_or_odd(num):
    """This function is even or odd"""
    if num&2 ==0:
        print("The number is even")
    else:
        print("The number is odd")

# %%
even_or_odd(24)
# Out:
# The number is even

# %%
## function with multiple parameters


def add(a,b):
    return a+b

add(2,4)
# Out:
# 6

# %%
## Default parameters

def greet(name):
    print(f"Hello {name}")

greet("Krish")
# Out:
# Hello Krish

# %%
## all others done in class
