# %% [markdown]
# Standard Library Overview

# %%
import array
arr=array.array('i', [1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import random 
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 8
# apple

# %%
### File and Directory access

import os
print(os.getcwd())
# Out:
# d:\CodewithAdi\Generative_AI_K_N\5-Modules

# %%
os.mkdir('test.dir')

# %%
## High level operation on files

import shutil
shutil.copyfile('text.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Sterilization

import json
data={'name':'Aditya', 'age':16}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Aditya", "age": 16}
# <class 'str'>
# {'name': 'Aditya', 'age': 16}
# <class 'dict'>

# %%
## csv

import csv

with open('example.csv', mode='w',newline='') as file:
  writer=csv.writer(file)
  writer.writerow(['name', 'age'])
  writer.writerow(['Aditya', 16])


with open('example.csv', mode='r') as file:
  reader=csv.reader(file)
  for row in reader:
    print(row)
# Out:
# ['name', 'age']
# ['Aditya', '16']

# %%
## date time

from datetime import datetime, timedelta

now=datetime.now()
print(now)
yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-06-17 23:27:14.458661
# 2026-06-16 23:27:14.458661

# %%
##time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1781704316.9959424
# 1781704319.0011132

# %%
## Regular expression
import re

pattern=r'\d+'
text='There are 69 apples 456'
match=re.search(pattern,text)
print(match.group())
# Out:
# 69
