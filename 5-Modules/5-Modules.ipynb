# %% [markdown]
# # Importing Modules in Python

# %%
import math

math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(25), sqrt(pi))
# Out:
# 5.0 1.7724538509055159

# %%
import numpy as np         # create arrays and particular operations from arrays
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from packages.maths import addition
addition(2,3)
# Out:
# 5

# %%
from packages import maths
