# %% [markdown]
# ## Wordnet Lemmatizer

# %%
## Q&A, chatbots, text summarization


from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemmatizer.lemmatize("going")
# Out:
# 'going'

# %%
'''
POS- 
Noun-n, verb - v, adjective - a, adverb - r
'''
lemmatizer.lemmatize("going", pos = 'v')
# Out:
# 'go'

# %%
words = ["nigga", "in", "which", "college", "does", "this", "shit", "happens", "like", "wtf", "fucking", "going", "finalized"]
for word in words:
  print(word + "----->" + lemmatizer.lemmatize(word, pos = 'v'))
# Out:
# nigga----->nigga
# in----->in
# which----->which
# college----->college
# does----->do
# this----->this
# shit----->shit
# happens----->happen
# like----->like
# wtf----->wtf
# fucking----->fuck
# going----->go
# finalized----->finalize

# %%
lemmatizer.lemmatize("goes", pos = 'v')
lemmatizer.lemmatize("fairly"), lemmatizer.lemmatize("sportingly")
# Out:
# ('fairly', 'sportingly')
