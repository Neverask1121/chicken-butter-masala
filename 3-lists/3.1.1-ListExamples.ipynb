# %%
to_do_list=["Buy the Groceries", "Clean the house", "Pay the Bills"]

##Adding tasks to list

to_do_list.append("Schedule s")
to_do_list.append("Go for a run")

to_do_list.remove("Buy the Groceries")


##Checking if the task is in the Todo List or not

if "Go for a run" in to_do_list:
    print("Don't forget to run nigga")

print("Remaining in the to-do List")
for task in to_do_list:
    print(f"-{task}")
# Out:
# Don't forget to run nigga
# Remaining in the to-do List
# -Clean the house
# -Pay the Bills
# -Schedule s
# -Go for a run
